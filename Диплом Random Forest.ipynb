# %%
import numpy as np
import pandas as pd
import cv2
import pytesseract
from PIL import Image
from pytesseract import Output
import os
import glob
import pathlib
from colorthief import ColorThief

# %%
df_old = pd.read_csv("/home/lev/Desktop/output4.csv")

# %%
df_new = pd.read_csv("/home/lev/Desktop/output5.csv")

# %%
df_old = df_old.set_index('image')

# %%
df_new = df_new.set_index('image')

# %%
result = pd.concat(
    [df_old, df_new],
    axis=0,
    join="outer",
    ignore_index=False,
    keys=None,
    levels=None,
    names=None,
    verify_integrity=False,
    copy=True,
)

# %%
result = pd.read_csv("/home/lev/Desktop/result_1405.csv")

# %%
result = result.reset_index()

# %%
result = result.drop_duplicates(subset='image').reset_index()

# %%
result = result.drop(['index', 'Unnamed: 0', 'level_0'], axis=1)

# %%
result
# Out:
#                                                  image  num_words  num_boxes  \
# 0    /home/lev/Desktop/diploma_local/ugly_design/00...         24          5
# 1    /home/lev/Desktop/diploma_local/ugly_design/01...         49         22
# 2    /home/lev/Desktop/diploma_local/ugly_design/00...         59         25
# 3    /home/lev/Desktop/diploma_local/ugly_design/02...         85         22
# 4    /home/lev/Desktop/diploma_local/ugly_design/02...         51          9
# ..                                                 ...        ...        ...
# 295  /home/lev/Desktop/diploma_local/nice_design/__...         54         22
# 296  /home/lev/Desktop/diploma_local/nice_design/__...         76         13
# 297  /home/lev/Desktop/diploma_local/nice_design/5a...         39         14
# 298  /home/lev/Desktop/diploma_local/nice_design/ph...         34          8
# 299  /home/lev/Desktop/diploma_local/nice_design/__...         65         20
#
#      num_contrast_boxes  contrast_rate_text_mean  \
# 0                     4                 4.610000
# 1                     2                 1.539545
# 2                     1                 1.177200
# 3                     8                 3.736364
# 4                     0                 1.145556
# ..                  ...                      ...
# 295                  19                17.934091
# 296                   9                11.434615
# 297                   7                 5.216154
# 298                   0                 1.178750
# 299                   6                 4.713000
#
#      contrast_mark_2_to_5_text_mean first_color_palette second_color_palette  \
# 0                          3.600000        (72, 87, 98)      (219, 121, 121)
# 1                          2.181818     (243, 246, 246)       (27, 134, 140)
# 2                          2.040000     (199, 201, 212)       (18, 145, 177)
# 3                          3.090909     (244, 118, 232)         (54, 54, 79)
# 4                          2.000000         (5, 21, 42)      (205, 199, 204)
# ..                              ...                 ...                  ...
# 295                        4.590909        (23, 23, 24)      (226, 216, 189)
# 296                        4.000000        (27, 27, 32)      (200, 204, 205)
# 297                        3.615385       (69, 32, 187)      (216, 126, 187)
# 298                        2.000000     (227, 219, 216)         (30, 26, 25)
# 299                        2.850000     (176, 206, 245)         (38, 44, 53)
#
#     third_color_palette  target  white_share  contrast_rate_palette  \
# 0       (143, 194, 216)       0       0.1010               2.580000
# 1        (229, 116, 86)       0       0.1835               3.296667
# 2         (130, 85, 81)       0       0.1350               2.663333
# 3       (230, 215, 227)       0       0.0000               5.050000
# 4        (28, 180, 230)       0       0.0010               6.296667
# ..                  ...     ...          ...                    ...
# 295     (135, 136, 140)       1       0.8956               6.696667
# 296     (112, 190, 223)       1       0.0231               6.456667
# 297     (155, 149, 177)       1       0.0467               3.036667
# 298       (206, 73, 78)       1       0.0042               6.596667
# 299        (91, 88, 96)       1       0.2544               4.933333
#
#      contrast_mark_2_to_5_palette  first_color_palette_dec  \
# 0                        2.333333                4740962.0
# 1                        2.666667               15988470.0
# 2                        2.666667               13093332.0
# 3                        3.666667               16021224.0
# 4                        3.666667                 333098.0
# ..                            ...                      ...
# 295                      3.666667                1513240.0
# 296                      4.000000                1776416.0
# 297                      2.666667                4530363.0
# 298                      3.666667               14932952.0
# 299                      3.333333               11587317.0
#
#      second_color_palette_dec  third_color_palette_dec  black_share
# 0                  14383481.0                9421528.0       0.0000
# 1                   1803916.0               15037526.0       0.0000
# 2                   1216945.0                8541521.0       0.0000
# 3                   3552847.0               15128547.0       0.0000
# 4                  13486028.0                1881318.0       0.0000
# ..                        ...                      ...          ...
# 295                14866621.0                8882316.0       0.0340
# 296                13159629.0                7388895.0       0.1299
# 297                14188219.0               10196401.0       0.0000
# 298                 1972761.0               13519182.0       0.0001
# 299                 2501685.0                5986400.0       0.0020
#
# [300 rows x 17 columns]

# %%
result['black_share'] = result['black_share'].fillna(0.00)

# %%
result
# Out:
#                                                  image  num_words  num_boxes  \
# 0    /home/lev/Desktop/diploma_local/ugly_design/00...         24          5
# 1    /home/lev/Desktop/diploma_local/ugly_design/01...         49         22
# 2    /home/lev/Desktop/diploma_local/ugly_design/00...         59         25
# 3    /home/lev/Desktop/diploma_local/ugly_design/02...         85         22
# 4    /home/lev/Desktop/diploma_local/ugly_design/02...         51          9
# ..                                                 ...        ...        ...
# 295  /home/lev/Desktop/diploma_local/nice_design/__...         54         22
# 296  /home/lev/Desktop/diploma_local/nice_design/__...         76         13
# 297  /home/lev/Desktop/diploma_local/nice_design/5a...         39         14
# 298  /home/lev/Desktop/diploma_local/nice_design/ph...         34          8
# 299  /home/lev/Desktop/diploma_local/nice_design/__...         65         20
#
#      num_contrast_boxes  contrast_rate_text_mean  \
# 0                     4                 4.610000
# 1                     2                 1.539545
# 2                     1                 1.177200
# 3                     8                 3.736364
# 4                     0                 1.145556
# ..                  ...                      ...
# 295                  19                17.934091
# 296                   9                11.434615
# 297                   7                 5.216154
# 298                   0                 1.178750
# 299                   6                 4.713000
#
#      contrast_mark_2_to_5_text_mean first_color_palette second_color_palette  \
# 0                          3.600000        (72, 87, 98)      (219, 121, 121)
# 1                          2.181818     (243, 246, 246)       (27, 134, 140)
# 2                          2.040000     (199, 201, 212)       (18, 145, 177)
# 3                          3.090909     (244, 118, 232)         (54, 54, 79)
# 4                          2.000000         (5, 21, 42)      (205, 199, 204)
# ..                              ...                 ...                  ...
# 295                        4.590909        (23, 23, 24)      (226, 216, 189)
# 296                        4.000000        (27, 27, 32)      (200, 204, 205)
# 297                        3.615385       (69, 32, 187)      (216, 126, 187)
# 298                        2.000000     (227, 219, 216)         (30, 26, 25)
# 299                        2.850000     (176, 206, 245)         (38, 44, 53)
#
#     third_color_palette  target  white_share  contrast_rate_palette  \
# 0       (143, 194, 216)       0       0.1010               2.580000
# 1        (229, 116, 86)       0       0.1835               3.296667
# 2         (130, 85, 81)       0       0.1350               2.663333
# 3       (230, 215, 227)       0       0.0000               5.050000
# 4        (28, 180, 230)       0       0.0010               6.296667
# ..                  ...     ...          ...                    ...
# 295     (135, 136, 140)       1       0.8956               6.696667
# 296     (112, 190, 223)       1       0.0231               6.456667
# 297     (155, 149, 177)       1       0.0467               3.036667
# 298       (206, 73, 78)       1       0.0042               6.596667
# 299        (91, 88, 96)       1       0.2544               4.933333
#
#      contrast_mark_2_to_5_palette  first_color_palette_dec  \
# 0                        2.333333                4740962.0
# 1                        2.666667               15988470.0
# 2                        2.666667               13093332.0
# 3                        3.666667               16021224.0
# 4                        3.666667                 333098.0
# ..                            ...                      ...
# 295                      3.666667                1513240.0
# 296                      4.000000                1776416.0
# 297                      2.666667                4530363.0
# 298                      3.666667               14932952.0
# 299                      3.333333               11587317.0
#
#      second_color_palette_dec  third_color_palette_dec  black_share
# 0                  14383481.0                9421528.0       0.0000
# 1                   1803916.0               15037526.0       0.0000
# 2                   1216945.0                8541521.0       0.0000
# 3                   3552847.0               15128547.0       0.0000
# 4                  13486028.0                1881318.0       0.0000
# ..                        ...                      ...          ...
# 295                14866621.0                8882316.0       0.0340
# 296                13159629.0                7388895.0       0.1299
# 297                14188219.0               10196401.0       0.0000
# 298                 1972761.0               13519182.0       0.0001
# 299                 2501685.0                5986400.0       0.0020
#
# [300 rows x 17 columns]

# %%
result = pd.read_csv("/home/lev/Desktop/result_1405.csv")

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

from sklearn import metrics
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#разделение набора данных
df_total = result.dropna()
features = ['num_words', 'num_boxes', 'num_contrast_boxes', 'contrast_rate_text_mean',
         'contrast_mark_2_to_5_text_mean', 'contrast_rate_palette', 'contrast_mark_2_to_5_palette', 'white_share', 'black_share',
         'first_color_palette_dec', 'second_color_palette_dec', 'third_color_palette_dec']

y = df_total.target
X = df_total[features].copy()

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.7, random_state=42,stratify=y)

# %%
X_train
# Out:
#      num_words  num_boxes  num_contrast_boxes  contrast_rate_text_mean  \
# 187         80         37                   6                 3.899459
# 50          30          7                   1                 1.807143
# 65         216         91                  13                 3.013077
# 125         33         10                   4                 6.318000
# 278         75         25                   6                 3.468400
# ..         ...        ...                 ...                      ...
# 5          184         77                  34                 9.696364
# 128         52         28                   5                 2.708929
# 222         39          8                   7                13.012500
# 120        106         54                   4                 1.896296
# 178         56          5                   0                 1.100000
#
#      contrast_mark_2_to_5_text_mean  contrast_rate_palette  \
# 187                        2.486486               7.470000
# 50                         2.285714               3.486667
# 65                         2.428571               5.686667
# 125                        3.200000               3.600000
# 278                        2.640000               4.323333
# ..                              ...                    ...
# 5                          3.324675               5.226667
# 128                        2.464286               6.323333
# 222                        4.375000               7.453333
# 120                        2.203704               5.693333
# 178                        2.000000               3.980000
#
#      contrast_mark_2_to_5_palette  white_share  black_share  \
# 187                      4.000000       0.1128       0.0000
# 50                       3.000000       0.0252       0.0000
# 65                       3.333333       0.0023       0.0000
# 125                      3.000000       0.0407       0.0000
# 278                      3.333333       0.0399       0.1979
# ..                            ...          ...          ...
# 5                        3.666667       0.0030       0.0000
# 128                      3.666667       0.0045       0.0000
# 222                      3.666667       0.7941       0.0000
# 120                      3.333333       0.1622       0.0000
# 178                      3.333333       0.0027       0.0000
#
#      first_color_palette_dec  second_color_palette_dec  \
# 187               16180715.0                10950436.0
# 50                10720639.0                 2302752.0
# 65                16119200.0                 1199127.0
# 125                3091777.0                 7590708.0
# 278               10986128.0                  921362.0
# ..                       ...                       ...
# 5                   527127.0                12687766.0
# 128                1118479.0                13552325.0
# 222               14277082.0                  328965.0
# 120               16174797.0                 2500912.0
# 178                2630948.0                12555904.0
#
#      third_color_palette_dec
# 187                3481379.0
# 50                 5978139.0
# 65                 9135701.0
# 125               11830650.0
# 278                6635379.0
# ..                       ...
# 5                  8165825.0
# 128                8684676.0
# 222                5789784.0
# 120               15360099.0
# 178                9671830.0
#
# [210 rows x 12 columns]

# %% [markdown]
# ## Обучение RF Classifier

# %%
# масштабирование данных
import numpy as np
from sklearn.preprocessing import StandardScaler
ss = StandardScaler()
X_train_scaled = ss.fit_transform(X_train)
X_test_scaled = ss.transform(X_test)
_y_train = np.array(y_train)

# %%
y_train
# Out:
# 187    1
# 50     0
# 65     0
# 125    1
# 278    0
#       ..
# 5      0
# 128    1
# 222    1
# 120    1
# 178    1
# Name: target, Length: 210, dtype: int64

# %%
X_train.isna().sum()
# Out:
# num_words                         0
# num_boxes                         0
# num_contrast_boxes                0
# contrast_rate_text_mean           0
# contrast_mark_2_to_5_text_mean    0
# contrast_rate_palette             0
# contrast_mark_2_to_5_palette      0
# white_share                       0
# black_share                       0
# first_color_palette_dec           0
# second_color_palette_dec          0
# third_color_palette_dec           0
# dtype: int64

# %%
# обучение модели
from sklearn.ensemble import RandomForestClassifier

rfc = RandomForestClassifier(n_estimators=3000, random_state=100)

#rfc.fit(X_train_scaled, y_train)
rfc.fit(X_train, y_train)

model = rfc.fit(X_train, y_train)

y_pred = rfc.predict(X_test)
y_pred_proba = rfc.predict_proba(X_test_scaled)

# %%
# Save predictions in suitable format
# reshape X_test сделать 
output = pd.DataFrame({'Id': X_test.index,
                       'target': y_pred})
output.set_index('Id')
# Out:
#      target
# Id
# 113       1
# 232       0
# 61        1
# 41        1
# 198       1
# ..      ...
# 224       0
# 185       0
# 240       1
# 92        1
# 74        0
#
# [90 rows x 1 columns]

# %%
output
# Out:
#      Id  target
# 0   113       1
# 1   232       0
# 2    61       1
# 3    41       1
# 4   198       1
# ..  ...     ...
# 85  224       0
# 86  185       0
# 87  240       1
# 88   92       1
# 89   74       0
#
# [90 rows x 2 columns]

# %%
result = X_test.merge(output, how="inner", left_on=X_test.index, right_on="Id").merge(df_total['image'], how="inner", left_on="Id", right_on=df_total.index).set_index('Id')

# %%
result.head()
# Out:
#      num_words  num_boxes  num_contrast_boxes  contrast_rate_text_mean  \
# Id
# 113         60         38                  28                 9.455000
# 232         69         42                   5                 1.524762
# 61          83         35                   8                 5.588857
# 41          32         12                   3                 4.355833
# 198         40          8                   1                 1.838750
#
#      contrast_mark_2_to_5_text_mean  contrast_rate_palette  \
# Id
# 113                        3.710526               3.036667
# 232                        2.119048               3.790000
# 61                         2.685714               6.360000
# 41                         2.666667               6.513333
# 198                        2.375000               4.666667
#
#      contrast_mark_2_to_5_palette  white_share  black_share  \
# Id
# 113                      2.666667       0.7107          0.0
# 232                      2.666667       0.0632          0.0
# 61                       3.333333       0.7475          0.0
# 41                       3.666667       0.0000          0.0
# 198                      3.333333       0.6453          0.0
#
#      first_color_palette_dec  second_color_palette_dec  \
# Id
# 113               10266291.0                 3030358.0
# 232               10576306.0                15258345.0
# 61                14867403.0                 1646633.0
# 41                  920844.0                14669911.0
# 198               13947858.0                 3618613.0
#
#      third_color_palette_dec  target  \
# Id
# 113                6179910.0       1
# 232                5714857.0       0
# 61                 8410952.0       1
# 41                 8490842.0       1
# 198                8412217.0       1
#
#                                                  image
# Id
# 113  /home/lev/Desktop/diploma_local/nice_design/00...
# 232  /home/lev/Desktop/diploma_local/nice_design/00...
# 61   /home/lev/Desktop/diploma_local/ugly_design/b8...
# 41   /home/lev/Desktop/diploma_local/ugly_design/d1...
# 198  /home/lev/Desktop/diploma_local/nice_design/00...

# %% [markdown]
# Если нам интересно узнать о том, какие признаки являются самыми важными для RF-модели в деле предсказания рака груди, мы можем визуализировать и квантифицировать показатели важности признаков, обратившись к атрибуту feature_importances_:

# %% [markdown]
# ## Метрики качества
# http://bioinformaticsinstitute.ru/sites/default/files/vvedenie_v_mashinnoe_obuchenie.pdf
#
# - confusion matrix
# - ROC
# - ROC AUC
# - accuracy (аккуратность) — процент верных предсказаний
# - recall  (полнота) — сколько из настоящих “Класс 1/да” мы
# определили верно (то же самое, что True Positive Rate,
# Sensitivity)
# - precision (точность) сколько верных среди предсказанных как
# “Класс 1/да”
# - F-мера (гармоническое среднее P и R)
#
# high precision relates to a low false positive rate, and high recall relates to a low false negative rate.
#
# The precision is the ratio tp / (tp + fp) where tp is the number of true positives and fp the number of false positives. The precision is intuitively the ability of the classifier to not label a sample as positive if it is negative.
#
# The recall is the ratio tp / (tp + fn) where tp is the number of true positives and fn the number of false negatives. The recall is intuitively the ability of the classifier to find all the positive samples.
#
# The F-beta score can be interpreted as a weighted harmonic mean of the precision and recall, where an F-beta score reaches its best value at 1 and worst score at 0.

# %%
from sklearn.metrics import recall_score

display(rfc.score(X_train, y_train))
# Out:
# 1.0

# %%
# Analyzing the results. 
from sklearn import metrics 
cnf_matrix = metrics.confusion_matrix(y_test, y_pred)

# %%
class_names=[0,1] # name  of classes
fig, ax = plt.subplots()
tick_marks = np.arange(len(class_names))
plt.xticks(tick_marks, class_names)
plt.yticks(tick_marks, class_names)
# create heatmap
sns.heatmap(pd.DataFrame(cnf_matrix), annot=True, cmap="YlGnBu" ,fmt='g')
ax.xaxis.set_label_position("top")
plt.tight_layout()
plt.title('Confusion matrix', y=1.1)
plt.ylabel('Actual label')
plt.xlabel('Predicted label')
# Out:
# Text(0.5, 257.44, 'Predicted label')

# %%
import sklearn.metrics as metrics
print(metrics.classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.53      0.49      0.51        41
#            1       0.60      0.63      0.61        49
#
#     accuracy                           0.57        90
#    macro avg       0.56      0.56      0.56        90
# weighted avg       0.56      0.57      0.56        90

# %%
print("Average Precision Score", metrics.average_precision_score(y_test, y_pred))
# Out:
# Average Precision Score 0.5771585557299843

# %%
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
score = roc_auc_score(y_test, y_pred)
fpr, tpr, thresholds = roc_curve(y_test, y_pred_proba[:,1])
plt.figure()
plt.plot(fpr, tpr, label='XGboost (area = %0.2f)' % score)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.savefig('Log_ROC')
plt.show()

# %% [markdown]
# ## Feature Importance

# %%
import shap

# explain the model's predictions using SHAP
# (same syntax works for LightGBM, CatBoost, scikit-learn, transformers, Spark, etc.)
explainer = shap.Explainer(model)
shap_values = explainer(X_test)

# visualize the first prediction's explanation
#shap.plots.waterfall(shap_values[0])

# summarize the effects of all the features
shap.plots.beeswarm(shap_values)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-122-713ec4d31887> in <module>
#      10
#      11 # summarize the effects of all the features
# ---> 12 shap.plots.beeswarm(shap_values)
#
# ~/Desktop/MAI/python_numpy_MAI/my_project_env/lib/python3.6/site-packages/shap/plots/_beeswarm.py in beeswarm(shap_values, max_display, order, clustering, cluster_threshold, color, axis_color, alpha, show, log_scale, color_bar, plot_size, color_bar_label)
#      52         elif len(shap_values.shape) > 2:
#      53             raise ValueError(
# ---> 54                 "The beeswarm plot does not support plotting explanations with instances that have more "
#      55                 "than one dimension!"
#      56             )
#
# ValueError: The beeswarm plot does not support plotting explanations with instances that have more than one dimension!

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

feats = {}
#for feature, importance in zip(df_total.columns, rfc.feature_importances_):
for feature, importance in zip(features, rfc.feature_importances_):
    feats[feature] = importance
importances = pd.DataFrame.from_dict(feats, orient='index').rename(columns={0: 'Gini-Importance'})
importances = importances.sort_values(by='Gini-Importance', ascending=False)
importances = importances.reset_index()
importances = importances.rename(columns={'index': 'Features'})
sns.set(font_scale = 5)
sns.set(style="whitegrid", color_codes=True, font_scale = 1.7)
fig, ax = plt.subplots()
fig.set_size_inches(30,15)
sns.barplot(x=importances['Gini-Importance'], y=importances['Features'], data=importances, color='skyblue')
plt.xlabel('Importance', fontsize=25, weight = 'bold')
plt.ylabel('Features', fontsize=25, weight = 'bold')
plt.title('Feature Importance', fontsize=25, weight = 'bold')
display(plt.show())
display(importances)
# Out:
# None
#                           Features  Gini-Importance
# 0                        num_words         0.130946
# 1         second_color_palette_dec         0.122395
# 2            contrast_rate_palette         0.121602
# 3                        num_boxes         0.098576
# 4          third_color_palette_dec         0.093505
# 5          first_color_palette_dec         0.093053
# 6          contrast_rate_text_mean         0.081677
# 7                      white_share         0.075681
# 8   contrast_mark_2_to_5_text_mean         0.065555
# 9               num_contrast_boxes         0.052950
# 10    contrast_mark_2_to_5_palette         0.036321
# 11                     black_share         0.027737
